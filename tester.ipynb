# %%
from clustering_model import Clustering_Model
# Out:
# /usr/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: compiletime version 3.5 of module 'gurobipy' does not match runtime version 3.4
#   return f(*args, **kwds)

# %%
def read_graph(graph_fname, cons_fname=None):
    node_names = dict()
    node_ids = dict()
    edges = set()
    
    def get_id(name):
        if not name in node_names:
            node_id = len(node_names)
            node_names[name] = node_id
            node_ids[node_id] = name 

        return node_names[name]  

    def add_edge(v1, v2):
        first = min(v1, v2)
        second = max(v1, v2)
        edges.add((first, second))


    with open(graph_fname) as f:
        f.readline()
        for line in f:
            line = line.strip()
            if not line: continue
            [n1, n2] = line.strip().split(',')
            [v1, v2] = [get_id(i) for i in (n1, n2)]
            add_edge(v1, v2)

    n_vertices = max(node_ids.keys()) + 1
    
    
    constraints = []
    if cons_fname is not None:
        with open(cons_fname) as f:
            f.readline()
            for line in f:
                line = line.strip()
                if not line: continue
                [n1, n2, w] = line.split(',')
                [v1, v2] = [get_id(i) for i in (n1, n2)]
                w = float(w)
                constraints.append((v1, v2, w))
    
    return n_vertices, list(edges), constraints, node_ids

# %%
n_vertices, edges, constraints, _ = read_graph('./data/graph.csv', 'data/graph_cannot_links.csv')
k = 3

# %%
cm = Clustering_Model(n_vertices, edges, 
                      constraints=constraints, 
                      k=k, gamma=10, verbosity=1)
# Out:
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter PreCrush to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0
# Changed value of parameter LazyConstraints to 1
#    Prev: 0  Min: 0  Max: 1  Default: 0

# %%
cm.solve()
# Out:
# Optimize a model with 291 rows, 343 columns and 948 nonzeros
# Coefficient statistics:
#   Matrix range    [1e+00, 1e+00]
#   Objective range [2e-01, 1e+01]
#   Bounds range    [1e+00, 3e+01]
#   RHS range       [1e+00, 1e+00]
# Found heuristic solution: objective -190.749
# Presolve time: 0.00s
# Presolved: 291 rows, 343 columns, 948 nonzeros
# Variable types: 0 continuous, 343 integer (342 binary)
#
# Root relaxation: objective 9.000000e+00, 94 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    9.00000    0   34 -190.74865    9.00000   105%     -    0s
# H    0     0                    -130.3629521    9.00000   107%     -    0s
# H    0     0                    -118.3629522    9.00000   108%     -    0s
#      0     0    9.00000    0   46 -118.36295    9.00000   108%     -    0s
#      0     0    9.00000    0   62 -118.36295    9.00000   108%     -    0s
# H    0     0                    -117.3583932    9.00000   108%     -    0s
# H    0     0                     -95.7205581    9.00000   109%     -    0s
#      0     0    9.00000    0   46  -95.72056    9.00000   109%     -    0s
#      0     0    9.00000    0   46  -95.72056    9.00000   109%     -    0s
# H    0     2                     -94.2766232    9.00000   110%     -    0s
#      0     2    9.00000    0   40  -94.27662    9.00000   110%     -    0s
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 67, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 67, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 67, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 67, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 67, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 67, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# H   49    51                     -74.8526821    9.00000   112%  42.7    0s
# H   81    81                     -73.8526821    9.00000   112%  35.7    0s
# H  245   187                     -72.8526821    9.00000   112%  23.7    0s
# H  312   215                     -63.8684216    9.00000   114%  24.8    0s
# H  515   270                     -55.5780701    2.94279   105%  22.1    0s
# H  829   392                     -55.3802577    0.59010   101%  21.1    0s
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# * 1426   534              14     -54.7284459   -4.32546  92.1%  19.2    0s
# * 3015   869              13     -54.5209276  -12.91332  76.3%  18.2    0s
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Exception ignored in: 'gurobipy.callbackstub'
# Traceback (most recent call last):
#   File "callback.pxi", line 155, in gurobipy.CallbackClass.callback (../../src/python/gurobipy.c:77348)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 75, in mincut_callback
#     cutsets = model._cutfinder.get_cutsets(capacities)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 44, in get_cutsets
#     cutset = self.find_cutset(in1, in2)
#   File "/cw/dtailocal/behrouz/temp/test_notebooks/dries/clustering_model.py", line 29, in find_cutset
#     _, (reachable, non_reachable) = nx.minimum_cut(self.G, in1*2+1, in2*2)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/maxflow.py", line 448, in minimum_cut
#     R = flow_func(G, s, t, capacity=capacity, value_only=True, **kwargs)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 422, in preflow_push
#     value_only)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/preflowpush.py", line 40, in preflow_push_impl
#     detect_unboundedness(R, s, t)
#   File "/home/behrouz/.local/lib/python3.4/site-packages/networkx/algorithms/flow/utils.py", line 157, in detect_unboundedness
#     'Infinite capacity path, flow unbounded above.')
# networkx.exception.NetworkXUnbounded: Infinite capacity path, flow unbounded above.
# Explored 9840 nodes (147679 simplex iterations) in 1.63 seconds
# Thread count was 4 (of 4 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.452092763142e+01, best bound -5.452092763142e+01, gap 0.0%
# [[0, 6, 7, 8, 10, 12, 16, 21, 23, 25],
#  [1, 2, 9, 11, 13, 14, 15, 17, 18, 20, 24, 26],
#  [3, 4, 5, 19, 22]]
